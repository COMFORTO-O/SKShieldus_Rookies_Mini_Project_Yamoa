# %%
# 팀 승률, 순위 등의 통계

from selenium import webdriver
from bs4 import BeautifulSoup
import time

driver = webdriver.Chrome()
driver.get("https://www.koreabaseball.com/Record/TeamRank/TeamRankDaily.aspx")

time.sleep(2)

soup = BeautifulSoup(driver.page_source, 'html.parser')
table = soup.find('table', class_='tData')

team_data = []

for row in table.select('tbody > tr'):
    cols = row.find_all('td')
    if len(cols) > 1:
        rank = cols[0].text.strip()
        team = cols[1].text.strip()
        plays = cols[2].text.strip()
        win = cols[3].text.strip()
        lose = cols[4].text.strip()
        draw = cols[5].text.strip()
        win_rate = cols[6].text.strip()
        
        team_info = {
            '순위': rank,
            '팀명': team,
            '경기': plays,
            '승': win,
            '패': lose,
            '무': draw,
            '승률': win_rate
        }
        team_data.append(team_info)

driver.quit()

team_data

# %%
# 타자 선수 개인 기록 및 누적 데이터 수집
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

url = 'https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx?sort=HRA_RT'
driver = webdriver.Chrome()
driver.get(url)
time.sleep(3)

hitter_players = []

for page in range(1, 4):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    table = soup.find('table', class_='tData01 tt')

    for row in table.select('tbody > tr'):
        cols = row.find_all('td')
        if len(cols) > 1:
            rank = cols[0].text.strip()
            name = cols[1].text.strip()
            team = cols[2].text.strip()
            avg = cols[3].text.strip()
            g = cols[4].text.strip()
            pa = cols[5].text.strip()
            ab = cols[6].text.strip()
            r = cols[7].text.strip()
            h = cols[8].text.strip()
            two_b = cols[9].text.strip()
            three_b = cols[10].text.strip()
            hr = cols[11].text.strip()
            tb = cols[12].text.strip()
            rbi = cols[13].text.strip()
            sac = cols[14].text.strip()
            sf = cols[15].text.strip()
            hitter_players.append({'순위': rank, '선수명': name, '팀명': team, '타율': avg, '경기': g, '타석': pa, '타수': ab, '득점': r, '안타': h, '2루타': two_b, '3루타': three_b, '홈런': hr, '루타': tb, '타점': rbi, '희생번트': sac, '희생플라이': sf})

    try:
        next_button = driver.find_element(By.LINK_TEXT, str(page + 1))
        next_button.click()
        time.sleep(2)
    except Exception as e:
        break

driver.quit()

hitter_players

# %%
# 투수 선수 개인 기록 및 누적 데이터 수집

from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

url = 'https://www.koreabaseball.com/Record/Player/PitcherBasic/BasicOld.aspx'
driver = webdriver.Chrome()
driver.get(url)
time.sleep(3)

Pitcher_players = []

for page in range(1, 4):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    table = soup.find('table', class_='tData01 tt')

    for row in table.select('tbody > tr'):
        cols = row.find_all('td')
        if len(cols) > 1:
            rank = cols[0].text.strip()
            name = cols[1].text.strip()
            team = cols[2].text.strip()
            avg = cols[3].text.strip()
            g = cols[4].text.strip()
            cg = cols[5].text.strip()
            sho = cols[6].text.strip()
            w = cols[7].text.strip()
            l = cols[8].text.strip()
            sv = cols[9].text.strip()
            hld = cols[10].text.strip()
            wpct = cols[11].text.strip()
            tbf = cols[12].text.strip()
            ip = cols[13].text.strip()
            h = cols[14].text.strip()
            hr = cols[15].text.strip()
            bb = cols[16].text.strip()
            hbp = cols[17].text.strip()
            so = cols[18].text.strip()
            r = cols[19].text.strip()
            er = cols[20].text.strip()
            Pitcher_players.append({'순위': rank, '선수명': name, '팀명': team, '평균자책점': era, '경기': g, '완투': cg, '완봉': sho, '승리': w, '패배': l, '세이브': sv, '홀드': hld, '승률': wpct, '타자수': tbf, '이닝': ip, '피안타': h, '홈런': hr, '볼넷': bb, '사구': hbp, '삼진': so, '실점': r, '자책점': er})

    try:
        next_button = driver.find_element(By.LINK_TEXT, str(page + 1))
        next_button.click()
        time.sleep(2)
    except Exception as e:
        break

driver.quit()

Pitcher_players
